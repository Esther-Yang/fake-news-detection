# %% [markdown]
# # 2-3 Exploratory analysis - 6 classes - statements

# %%
# %load_ext autoreload
# %autoreload 2

from import_file import*

# %%
path = Path.cwd() / "processed_data" / "df_raw.pkl"
df_raw = pd.read_pickle(path)

# %% [markdown]
# ## Function to generate wordcloud

# %%
def generate_wordcloud(df, labeltype):
    wordcloud = WordCloud(width=3000, height=2000, background_color='white',stopwords=STOPWORDS).generate(str(df))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.title("Word Cloud of %s Statements in LIAR-PLUS dataset" %labeltype)
    plt.show()

# %% [markdown]
# ## Generate dataframes for statements

# %%
# For all statements
df_all = df_raw.loc[:, ['statement']]
print(df_all.shape)
print(df_all.head())
# Out:
# (12836, 1)
#                                              statement
# 0.0  Says the Annies List political group supports ...
# 1.0  When did the decline of coal start? It started...
# 2.0  "Hillary Clinton agrees with John McCain ""by ...
# 3.0  Health care reform legislation is likely to ma...
# 4.0  The economic turnaround started at the end of ...

# %%
# For true statements
df_true = df_raw.loc[df_raw['label']=='true',['statement']]
print(df_true.shape)
print(df_true.head())
# Out:
# (2063, 1)
#                                               statement
# 5.0   The Chicago Bears have had more starting quart...
# 16.0  McCain opposed a requirement that the governme...
# 30.0           Says Paul Ryan is still endorsing Trump.
# 35.0  We have a federal government that thinks they ...
# 36.0  Austin is a city that has basically doubled in...

# %%
# For mostly-true statments
df_mostlytrue = df_raw.loc[df_raw['label']=='mostly-true',['statement']]
print(df_mostlytrue.shape)
print(df_mostlytrue.head())
# Out:
# (2466, 1)
#                                               statement
# 2.0   "Hillary Clinton agrees with John McCain ""by ...
# 9.0   Says GOP primary opponents Glenn Grothman and ...
# 10.0  For the first time in history, the share of th...
# 13.0  The economy bled $24 billion due to the govern...
# 19.0  Almost 100,000 people left Puerto Rico last year.

# %%
# For half-true statments
df_halftrue = df_raw.loc[df_raw['label']=='half-true',['statement']]
print(df_halftrue.shape)
print(df_halftrue.head())
# Out:
# (2638, 1)
#                                               statement
# 1.0   When did the decline of coal start? It started...
# 4.0   The economic turnaround started at the end of ...
# 7.0   I'm the only person on this stage who has work...
# 8.0   However, it took $19.5 million in Oregon Lotte...
# 11.0  Since 2000, nearly 12 million Americans have s...

# %%
# For barely-true statments
df_barelytrue = df_raw.loc[df_raw['label']=='barely-true',['statement']]
print(df_barelytrue.shape)
print(df_barelytrue.head())
# Out:
# (2108, 1)
#                                               statement
# 6.0   Jim Dunnam has not lived in the district he re...
# 14.0  Most of the (Affordable Care Act) has already ...
# 17.0  U.S. Rep. Ron Kind, D-Wis., and his fellow Dem...
# 24.0  Says Mitt Romney wants to get rid of Planned P...
# 31.0  If you look at states that are right to work, ...

# %%
# For false statments
df_false = df_raw.loc[df_raw['label']=='false',['statement']]
print(df_false.shape)
print(df_false.head())
# Out:
# (2511, 1)
#                                               statement
# 0.0   Says the Annies List political group supports ...
# 3.0   Health care reform legislation is likely to ma...
# 12.0  When Mitt Romney was governor of Massachusetts...
# 20.0  Women and men both are making less when you ad...
# 25.0              I dont know who (Jonathan Gruber) is.

# %%
# For pants-fire statments
df_pantsfire = df_raw.loc[df_raw['label']=='pants-fire',['statement']]
print(df_pantsfire.shape)
print(df_pantsfire.head())
# Out:
# (1050, 1)
#                                               statement
# 38.0  In the case of a catastrophic event, the Atlan...
# 42.0  Rep. David Cicilline is responsible for the fe...
# 43.0  Says Ohio budget item later signed into law by...
# 46.0  Obamacare will provide insurance to all non-U....
# 48.0  It was under Barack Obama and Hillary Clinton ...

# %% [markdown]
# ## Generate wordclouds

# %%
generate_wordcloud(df_all, 'all')

generate_wordcloud(df_true, 'true')
generate_wordcloud(df_mostlytrue, 'mostly-true')
generate_wordcloud(df_halftrue, 'half-true')
generate_wordcloud(df_barelytrue, 'barely-true')
generate_wordcloud(df_false, 'false')
generate_wordcloud(df_pantsfire, 'pants-fire')
